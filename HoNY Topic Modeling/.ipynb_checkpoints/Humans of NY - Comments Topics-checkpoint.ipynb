# %% [markdown]
# ## Topic modeling for Humans of New York comments

# %%
#Similar process to the Humans of New York posts. However, there are ~6.5k posts in contrast to over 2 million comments
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from textblob import TextBlob, Word
from nltk.stem.snowball import SnowballStemmer
from sklearn.cluster import DBSCAN
import numpy as np
from gensim.corpora import Dictionary, MmCorpus
from gensim.models.ldamulticore import LdaMulticore
import pyLDAvis
import pyLDAvis.gensim
import warnings
import cPickle as pickle
import json
import itertools as it
import os
from gensim.models import Phrases
from gensim.models.word2vec import LineSentence
import codecs
import spacy
import re
# %matplotlib inline
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.
# C:\Anaconda2\lib\site-packages\ipykernel\pylab\config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# C:\Anaconda2\lib\site-packages\ipykernel\pylab\config.py:71: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   'retina', 'jpeg', 'svg', 'pdf'.""")
# C:\Anaconda2\lib\site-packages\ipykernel\pylab\config.py:85: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   use `figure_formats` instead)""")
# ...

# %%
#Comments were downloaded over several time periods and thus there are multiple files
#These comments correspond to the latest 390 Humans of New York posts
df1 = pd.read_csv('humansofnewyork_facebook_comments+part+1.csv')
df2 = pd.read_csv('humansofnewyork_facebook_comments+part+2.csv')
df3 = pd.read_csv('humansofnewyork_facebook_comments+part+3.csv')
df4 = pd.read_csv('humansofnewyork_facebook_comments+part+4.csv')
df5 = pd.read_csv('humansofnewyork_facebook_comments+part+5.csv')

# %%
#Data joined and duplicates deleted
df = pd.concat([df1,df2,df3,df4,df5], axis = 0)
df.drop_duplicates(inplace = True)
df.reset_index(inplace = True, drop = True)

# %%
df.head()
# Out:
#                           comment_id                         status_id  \
# 0  1403321913075238_1403322236408539  102099916530784_1403321913075238
# 1  1403321913075238_1403322469741849  102099916530784_1403321913075238
# 2  1403321913075238_1403322739741822  102099916530784_1403321913075238
# 3  1403321913075238_1113308078717724  102099916530784_1403321913075238
# 4  1403321913075238_1156069464481151  102099916530784_1403321913075238
#
#                            parent_id comment_message        comment_author  \
# 0                                NaN          First!     Kay E. Kensington
# 1  1403321913075238_1403322236408539         *claps*           Adam Mercer
# 2  1403321913075238_1403322236408539           I am.   Feras Mahmoud Ataya
# 3  1403321913075238_1403322236408539            Nope         Carl Sustrich
# 4  1403321913075238_1403322236408539           Fail!  John Amin Love Joyea
#
#      comment_published  comment_likes
# 0  2016-10-14 17:54:29           14.0
# ...

# %%
def remove_emoji(x):
    try:
        emoji_pattern = re.compile("["
            u"\U0001F600-\U0001F64F"  # emoticons
            u"\U0001F300-\U0001F5FF"  # symbols & pictographs
            u"\U0001F680-\U0001F6FF"  # transport & map symbols
            u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
            u"\u270c"           #one-off emojis
            u"\u2764"
            u"\u2764"
                               "]+", flags=re.UNICODE)
        return emoji_pattern.sub(r'', unicode(x)) # no emoji
    except:
        return np.NaN

def test():
    try:
        x=0
        for i in range(1000,10000):
            x=i
            remove_emoji(df.comment_message[i])
    except:
        print x
    
#test()

# %%
remove_emoji(df.comment_message[0])
# Out:
# u'First!'

# %%
df.comment_message[0]
# Out:
# 'First!'

# %%
df['comment_message_clean'] = df.comment_message.apply(remove_emoji)
#df['comment_message_clean'] = df.comment_message_clean.apply(remove_emoji)

# %%
def sentiment(x):
    try:
        return TextBlob(str(x)).sentiment.polarity
    except:
        return np.NaN

# %%
df['comment_sentiment'] = df.comment_message.apply(sentiment)

# %%
df_copy = df[df['comment_sentiment'].isnull()==True].copy(deep = True)

# %%
df_copy.shape
# Out:
# (391084, 9)

# %%
df_copy = df[df['comment_message_clean'].isnull()==True].copy(deep = True)

# %%
df_copy.comment_message = df_copy.comment_message.apply(lambda x: x.decode("utf-8"))

# %%
df_copy.comment_message = df_copy.comment_message.apply(remove_emoji)

# %%
df.loc[df_copy.index.tolist(),"comment_message_clean"]  = df_copy.comment_message.values.tolist()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-100-42258d103064> in <module>()
# ----> 1 df.loc[df_copy.index.tolist(),"comment_message_clean"]  = df_copy.comment_message.values.tolist()
#
# /home/ec2-user/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in __setitem__(self, key, value)
#     130             key = com._apply_if_callable(key, self.obj)
#     131         indexer = self._get_setitem_indexer(key)
# --> 132         self._setitem_with_indexer(indexer, value)
#     133
#     134     def _has_valid_type(self, k, axis):
#
# /home/ec2-user/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _setitem_with_indexer(self, indexer, value)
#     503
#     504                 # we have an equal len ndarray/convertible to our labels
# --> 505                 elif np.array(value).ndim == 2:
#     506
# ...

# %%
df_copy.comment_message[241]
# Out:
# u'Kat Crist I completely agree! \u270c\ufe0f'

# %%
df_copy.comment_message[321]
# Out:
# u'\u2764'

# %%
df_copy.comment_message[261]
# Out:
# u'What a great outlook and attitude!  \u2764\ufe0f'

# %% [markdown]
# ## Argument Detection

# %%
arguments = pd.DataFrame(df.groupby(['status_id','parent_id']).comment_id.count())
arguments.reset_index(inplace = True)
arguments.rename(columns = {'comment_id':'replies'}, inplace = True)

# %%
arguments.head()
# Out:
#                           status_id                          parent_id  \
# 0  102099916530784_1157449734329125  1157449734329125_1157450264329072
# 1  102099916530784_1157449734329125  1157449734329125_1157450417662390
# 2  102099916530784_1157449734329125  1157449734329125_1157450424329056
# 3  102099916530784_1157449734329125  1157449734329125_1157450450995720
# 4  102099916530784_1157449734329125  1157449734329125_1157450464329052
#
#    replies
# 0        1
# 1        2
# 2        1
# 3        3
# 4        2

# %%
sns.boxplot(arguments['replies'])

# %%
arguments['replies'].describe()
# Out:
# count    262385.000000
# mean          2.990716
# std          29.530880
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           2.000000
# max        8001.000000
# Name: replies, dtype: float64

# %%
plt.boxplot(df_stats['AngryToLove'])

# %%
sns.boxplot(df_stats['AngryToLove'])

# %%
df_stats['AngryToLove'].describe()

# %%
df_stats.sort('AngryToLove')

# %%
nlp = spacy.load('en')

# %%
sample = df.comment_message[0]
sample = sample.decode('utf-8')
sample
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-e20a6cb17a71> in <module>()
#       1 sample = df.comment_message[0]
# ----> 2 sample = sample.decode('utf-8')
#       3 sample
#
# /home/ec2-user/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'decode'

# %%
df.dtypes
# Out:
# comment_id            object
# status_id             object
# parent_id             object
# comment_message       object
# comment_author        object
# comment_published     object
# comment_likes        float64
# dtype: object

# %%
intermediate_directory = os.path.join('intermediate_comments')
review_txt_filepath = os.path.join(intermediate_directory,
                                   'review_text_all.txt')

# %%
review_count = 0
df.dropna(subset=['comment_message'],inplace=True)
df.reset_index(inplace=True, drop=True)
# create & open a new file in write mode
with codecs.open(review_txt_filepath, 'w', encoding='utf_8') as review_txt_file:


            # loop through all reviews in the existing file and convert to dict
    for i in range(0,len(df.comment_message)):
        #review = json.loads(review_json)
        holder = df.comment_message[i].decode('utf-8') 
        review_txt_file.write(holder + '\n')
        review_count += 1
        #print u'''Text from {:,} HoNY comment written to the new txt file.'''.format(review_count)

# %%
def punct_space(token):
    """
    helper function to eliminate tokens
    that are pure punctuation or whitespace
    """
    
    return token.is_punct or token.is_space

def line_review(filename):
    """
    generator function to read in reviews from the file
    and un-escape the original line breaks in the text
    """
    
    with codecs.open(filename, encoding='utf_8') as f:
        for review in f:
            yield review.replace('\\n', '\n')
            
def lemmatized_sentence_corpus(filename):
    """
    generator function to use spaCy to parse reviews,
    lemmatize the text, and yield sentences
    """
    
    for parsed_review in nlp.pipe(line_review(filename),
                                  batch_size=10000, n_threads=4):
        
        for sent in parsed_review.sents:
            yield u' '.join([token.lemma_ for token in sent
                             if not punct_space(token)])

# %%
unigram_sentences_filepath = os.path.join(intermediate_directory,
                                          'unigram_sentences_all.txt')

# %%
with codecs.open(unigram_sentences_filepath, 'w', encoding='utf_8') as f:
        for sentence in lemmatized_sentence_corpus(review_txt_filepath):
            f.write(sentence + '\n')

# %%
unigram_sentences = LineSentence(unigram_sentences_filepath)

# %%
for unigram_sentence in it.islice(unigram_sentences, 230, 240):
    print u' '.join(unigram_sentence)
    print u''
# Out:
# make the extra work for you not for them
#
# of course they appreciate it
#
# but when you become no longer so valuable because of illness or a change in the business your employer will make a decision base on what ' good for the business and what ' require by law
#
# a lot of people feel betray when they learn this the hard way
#
# virginia surdel one thing to keep in mind be that city employee often have solid union backing that help against unfair age base termination like that
#
# @alison cherry i do not know about others but i do not speak out of hate for anything
#
# but i be realistic
#
# unfortunately we have disastrous social and worker right and protection here so what happen to this man happen to thousand of people
#
# immigrant or not everyone can lose a job in a blink of an eye without previous notice or be tell 5 day ahead
#
# when you lose a job there be no bonus compensation

# %%
bigram_model_filepath = os.path.join(intermediate_directory, 'bigram_model_all')

# %%
bigram_model = Phrases(unigram_sentences)
bigram_model.save(bigram_model_filepath)
bigram_model = Phrases.load(bigram_model_filepath)

# %%
bigram_sentences_filepath = os.path.join(intermediate_directory,
                                         'bigram_sentences_all.txt')

# %%
with codecs.open(bigram_sentences_filepath, 'w', encoding='utf_8') as f:
        
        for unigram_sentence in unigram_sentences:
            
            bigram_sentence = u' '.join(bigram_model[unigram_sentence])
            
            f.write(bigram_sentence + '\n')

# %%
bigram_sentences = LineSentence(bigram_sentences_filepath)

# %%
for bigram_sentence in it.islice(bigram_sentences, 230, 240):
    print u' '.join(bigram_sentence)
    print u''
# Out:
# make the extra work for you not for them
#
# of course they appreciate it
#
# but when you become no_longer so valuable because of illness or a change in the business your employer will make a decision base_on what ' good for the business and what ' require by law
#
# a lot of people feel betray when they learn this the hard way
#
# virginia surdel one thing to keep in mind be that city employee often have solid union backing that help against unfair age base termination like that
#
# @alison cherry i do not know about others but i do not speak out of hate for anything
#
# but i be realistic
#
# unfortunately we have disastrous social and worker right and protection here so what happen to this man happen to thousand of people
#
# immigrant or not everyone can lose a job in a blink of an eye without previous notice or be tell 5 day ahead
#
# when you lose a job there be no bonus compensation

# %%
trigram_model_filepath = os.path.join(intermediate_directory,
                                      'trigram_model_all')

# %%
trigram_model = Phrases(bigram_sentences)
trigram_model.save(trigram_model_filepath)
trigram_model = Phrases.load(trigram_model_filepath)

# %%
trigram_sentences_filepath = os.path.join(intermediate_directory,
                                          'trigram_sentences_all.txt')

# %%
with codecs.open(trigram_sentences_filepath, 'w', encoding='utf_8') as f:
        
        for bigram_sentence in bigram_sentences:
            trigram_sentence = u' '.join(trigram_model[bigram_sentence])
            f.write(trigram_sentence + '\n')

# %%
trigram_sentences = LineSentence(trigram_sentences_filepath)

# %%
for trigram_sentence in it.islice(trigram_sentences, 230, 240):
    print u' '.join(trigram_sentence)
    print u''
# Out:
# make the extra work for you not for them
#
# of course they appreciate it
#
# but when you become no_longer so valuable because of illness or a change in the business your employer will make a decision_base_on what ' good for the business and what ' require by law
#
# a lot of people feel betray when they learn this the hard way
#
# virginia surdel one thing to keep in mind be that city employee often have solid union backing that help against unfair age base termination like that
#
# @alison cherry i do not know about others but i do not speak out of hate for anything
#
# but i be realistic
#
# unfortunately we have disastrous social and worker right and protection here so what happen to this man happen to thousand of people
#
# immigrant or not everyone can lose a job in a blink of an eye without previous notice or be tell 5 day ahead
#
# when you lose a job there be no bonus compensation

# %%
trigram_reviews_filepath = os.path.join(intermediate_directory,
                                        'trigram_transformed_reviews_all.txt')

# %%
with codecs.open(trigram_reviews_filepath, 'w', encoding='utf_8') as f:
        
        for parsed_review in nlp.pipe(line_review(review_txt_filepath),
                                      batch_size=10000, n_threads=4):
            
            # lemmatize the text, removing punctuation and whitespace
            unigram_review = [token.lemma_ for token in parsed_review
                              if not punct_space(token)]
            
            # apply the first-order and second-order phrase models
            bigram_review = bigram_model[unigram_review]
            trigram_review = trigram_model[bigram_review]
            
            # remove any remaining stopwords
            trigram_review = [term for term in trigram_review
                              if term not in spacy.en.STOPWORDS]
            
            # write the transformed review as a line in the new file
            trigram_review = u' '.join(trigram_review)
            f.write(trigram_review + '\n')

# %%
print u'Original:' + u'\n'

for review in it.islice(line_review(review_txt_filepath), 4011, 4012):
    print review

print u'----' + u'\n'
print u'Transformed:' + u'\n'

with codecs.open(trigram_reviews_filepath, encoding='utf_8') as f:
    for review in it.islice(f, 4011, 4012):
        print review
# Out:
# Original:
#
# amazing attitude that we can all learn from
#
# ----
#
# Transformed:
#
# amazing attitude learn

# %%
trigram_dictionary_filepath = os.path.join(intermediate_directory,
                                           'trigram_dict_all.dict')

# %%
trigram_reviews = LineSentence(trigram_reviews_filepath)

# learn the dictionary by iterating over all of the reviews
trigram_dictionary = Dictionary(trigram_reviews)
    
# filter tokens that are very rare or too common from
# the dictionary (filter_extremes) and reassign integer ids (compactify)
trigram_dictionary.filter_extremes(no_below=10, no_above=0.4)
trigram_dictionary.compactify()

trigram_dictionary.save(trigram_dictionary_filepath)
    
# load the finished dictionary from disk
trigram_dictionary = Dictionary.load(trigram_dictionary_filepath)

# %%
trigram_bow_filepath = os.path.join(intermediate_directory,
                                    'trigram_bow_corpus_all.mm')

# %%
#generator function to read reviews from a file and yield a bag-of-words representation

def trigram_bow_generator(x):
    for message in LineSentence(x):
        yield trigram_dictionary.doc2bow(message)

# %%
# generate bag-of-words representations for all reviews and save them as a matrix
MmCorpus.serialize(trigram_bow_filepath,trigram_bow_generator(trigram_reviews_filepath))
    
# load the finished bag-of-words corpus from disk
trigram_bow_corpus = MmCorpus(trigram_bow_filepath)

# %%
lda_model_filepath = os.path.join(intermediate_directory, 'lda_model_all')

# %%
with warnings.catch_warnings():
        warnings.simplefilter('ignore')
        
        # workers => sets the parallelism, and should be
        # set to your number of physical cores minus one
        lda = LdaMulticore(trigram_bow_corpus,
                           num_topics=50,
                           id2word=trigram_dictionary,
                           workers=3)
    
lda.save(lda_model_filepath)
    
# load the finished LDA model from disk
lda = LdaMulticore.load(lda_model_filepath)

# %%
def explore_topic(topic_number, topn=25):
    """
    accept a user-supplied topic number and
    print out a formatted list of the top terms
    """
        
    print u'{:20} {}'.format(u'term', u'frequency') + u'\n'

    for term, frequency in lda.show_topic(topic_number, topn=25):
        print u'{:20} {:.3f}'.format(term, round(frequency, 3))

# %%
explore_topic(topic_number=0)
# Out:
# term                 frequency
#
# sweet                0.072
# 😂                    0.068
# wrong                0.057
# funny                0.040
# level                0.035
# benign               0.035
# freedom              0.026
# emily                0.023
# response             0.019
# full_human           0.018
# thread               0.015
# cycle                0.015
# conversation         0.015
# maria                0.013
# '                    0.013
# paul                 0.011
# r                    0.011
# hahah                0.011
# celebrate            0.010
# anthony              0.009
# release              0.008
# regardless           0.008
# think                0.008
# deeply               0.008
# olivia               0.007

# %%
LDAvis_data_filepath = os.path.join(intermediate_directory, 'ldavis_prepared')

# %%
LDAvis_prepared = pyLDAvis.gensim.prepare(lda, trigram_bow_corpus,
                                              trigram_dictionary)

with open(LDAvis_data_filepath, 'w') as f:pickle.dump(LDAvis_prepared, f)
        
# load the pre-prepared pyLDAvis data from disk
with open(LDAvis_data_filepath) as f:LDAvis_prepared = pickle.load(f)

# %%
pyLDAvis.display(LDAvis_prepared)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el4470139959499938640143031335"></div>
# <script type="text/javascript">
#
# ...
